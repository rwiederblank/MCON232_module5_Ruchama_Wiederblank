# %% [markdown]
# ## Building our CSV file named "student_data.csv"

# %%
data = ["name", "age", "major", "course", "grade",
        "Alice", 20, "CS", "Math", 90,
        "Alice", 20, "CS", "CS", 88,
        "Bob", 21, "Math", "Math", 85,
        "Bob", 21, "Math", "CS", 90]

# WRITE
count = 1
with open("student_data.csv", "w") as fout:
    for item in data:
        item = str(item)
        if count == len(data) :
            fout.write(item)
        elif count % 5 == 0:
            fout.write(item + "\n")
        else:
            fout.write(item + ",")   # cleaner CSV
        count += 1

student_list = {}

# %% [markdown]
# ## Exercise : to build a dictionary that looks like this
# ```
# students_demo = {
#     "Alice": {"age": 20, "major": "CS", "grades": {"Math": 90, "CS": 95}},
#     "Bob": {"age": 21, "major": "Math", "grades": {"Math": 85, "CS": 88}}
# }
# ```

# %%
# Your answer here

# %%
school = {
   "Alice": {
       "age": 20,
       "major": "CS",
       "grades": {
           "Math": 90,
           "CS": 95
       }
   },
   "Bob": {
       "age": 19,
       "major": "History",
       "grades": {
           "History": 88
       }
   },
   "Dina": {
       "age": 21,
       "major": "Math",
       "grades": {
           "Math": 100,
           "CS": 84
       }
   }
}

# %%
def add_student(school, student, age, major):
  if not isinstance(school, dict):
    raise TypeError("school must be a dictionary")
  if not isinstance(student, str) or student.strip() == "":
    raise ValueError("student must be string and it must not be empty")
  if not isinstance(age, int) or not 0 < age <= 25:
    raise ValueError("age is not correct range")
  if not isinstance(major, str) or major.strip() == "":
    raise ValueError("Major must be a non-empty string")
  if student not in school:
    school[student] = {"age": age, "major": major, "grades" : {}}
    return
  if not isinstance(school[student], dict):
    raise TypeError(f"{student} value should be a dictionary but is corrupted")
  if "age" not in school[student]:
    school[student]["age"] = age
  if "major" not in school[student]:
    school[student]["major"] = major
  if "grades" not in school[student]:
    school[student]["grades"] = {}
  if not isinstance(school[student]["grades"], dict):
    raise TypeError(f"Grades for {student} must be a dictionary ")
  print(f"We just entered: {school[student]}")


add_student(school, "Eliana", 19, "History")
# Out:
# We just entered: {'age': 19, 'major': 'History', 'grades': {}}

# %%
data = ["name", "age", "major", "course", "grade",
       "Alice", 20, "CS", "Math", 90,
       "Alice", 20, "CS", "CS", 88,
       "Bob", 21, "Math", "Math", 85,
       "Bob", 21, "Math", "CS", 90]
counts = 1
with open("student_data.csv", "w") as fout:
  for item in data:
    item = str(item)
    if count == len(data):
      fout.write(item)
    elif count % 5 == 0:
      fout.write(item + "\n")
    else:
      fout.write(item + ",")
    count += 1

with open("student_data.csv", "r") as f:
  count = 0
  students = {}
  headers = []
  for line in f:
    line = line.strip()
    if count == 0:
      my_list = line.split(",")
      for item in my_list:
        headers.append(item)
      count += 1
      continue
    my_list = line.split(",")
    students[my_list[0]] = {headers[1] : my_list[1], headers[2] : my_list[2], headers[3] : {my_list[3] : my_list[4]}}


print(students)
# Out:
# {'Alice': {'age': '20', 'major': 'CS', 'course': {'CS': '88'}}, 'Bob': {'age': '21', 'major': 'Math', 'course': {'CS': '90'}}}

# %%
student_list = {}

# READ -> NESTED DICT
def load_csv_data():
    with open("student_data.csv", "r") as fin:
        header = [h.strip() for h in fin.readline().strip().split(",")]

        for line in fin:
            parts = [p.strip() for p in line.strip().split(",")] # strip the line
            if len(parts) != 5: # expecting 5 elements in the line, if not reject and go on
                continue

            name, age, major, course, grade = parts # unpack
            age = int(age)
            grade = int(grade)

            if name not in student_list:
                student_list[name] = {"age": age, "major": major, "grades": {}}

            student_list[name]["grades"][course] = grade

load_csv_data()
print(student_list)
# Out:
# {'Alice': {'age': 20, 'major': 'CS', 'grades': {'Math': 90, 'CS': 88}}, 'Bob': {'age': 21, 'major': 'Math', 'grades': {'Math': 85, 'CS': 90}}}

# %% [markdown]
# ## Playing with Sets()

# %%
# return letters that are unique
def exactly_once(items):
  answer = []
  unseen = set(items)
  for item in items:
    if item in unseen:
      unseen.remove(item)
      answer.append(item)
    else:
      if item in answer:
        answer.remove(item)
  return answer


print(exactly_once([1,2,2,2,3,4]))
print(exactly_once(["a", "b", "c", "c", "d", "d"]))
# Out:
# [1, 3, 4]
# ['a', 'b']

# %%
def use_sets(nums):
  return len(set(nums)) != len(nums)

print(use_sets([1,1,1,2,3]))
print(use_sets([1,2,3]))
# Out:
# True
# False

# %% [markdown]
# ## Leetcode 217 :
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.

# %%
# answer

# %% [markdown]
# ## Leetcode 202 - Happy Number
# Write an algorithm to determine if a number n is happy.
#
# A happy number is a number defined by the following process:
#
# Starting with any positive integer, replace the number by the sum of the squares of its digits.
# Repeat the process until the number equals 1 (where it will stay), or it loops endlessly in a cycle which does not include 1.
# Those numbers for which this process ends in 1 are happy.
# Return true if n is a happy number, and false if not.
#
#
#
# Example 1:
#
# Input: n = 19
# Output: true
# Explanation:
# 1^2 + 9^2 = 82
# 8^2 + 2^2 = 68
# 6^2 + 8^2 = 100
# 1^2 + 0^2 + 02 = 1
# Example 2:
#
# Input: n = 2
# Output: false
#
#
# Constraints:
#
# 1 <= n <= 231 - 1

# %%
def cycle(num):
  if not isinstance(num, int):
    print("Not an int")
    return
  seen = set()

  while num != 1 and num not in seen:
    seen.add(num)
    num = sum(int(d) ** 2 for d in str(num))

  return num == 1
